# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sells = pd.read_csv('data/Propiedades-0701.csv')

# %%
# con esto borro una columna del dataframe (id, operation, place_with_parents_name, country_name, geonames_id(ver si sirve)
# lat-lon, price_aprox_local_currency, price_usd_per_m2, price_per_m2, floor, description, title, image_thumbnail)
sells = sells.drop(sells.columns[[0, 2, 5, 6, 8, 9, 14, 18, 19, 20, 24, 25, 26]], axis=1)

# %%
#house = sells[sells['property_type'] == 'PH']
#house.head(100)
sells.head(10)
# Out:
#    created_on property_type            place_name                state_name  \
# 0  2017-01-01         house               Quilmes    Bs.As. G.B.A. Zona Sur
# 1  2017-01-01         house               Punilla                   Córdoba
# 2  2017-01-01     apartment         Villa Urquiza           Capital Federal
# 3  2017-01-01     apartment         Villa Urquiza           Capital Federal
# 4  2017-01-01         house               Córdoba                   Córdoba
# 5  2017-01-01     apartment             San Telmo           Capital Federal
# 6  2017-01-01         house              La Plata    Bs.As. G.B.A. Zona Sur
# 7  2017-01-01         store  Centro / Microcentro           Capital Federal
# 8  2017-01-01         house          Río Ceballos                   Córdoba
# 9  2017-01-01     apartment                 Morón  Bs.As. G.B.A. Zona Oeste
#
#          lat        lon     price currency  price_aprox_usd  \
# 0 -34.744616 -58.277365       NaN      NaN              NaN
# 1 -31.447378 -64.518655  130000.0      USD        130000.00
# 2 -34.579461 -58.477982  109000.0      USD        109000.00
# 3 -34.579461 -58.477982   89900.0      USD         89900.00
# 4        NaN        NaN  795000.0      ARS         48443.11
# 5 -34.622790 -58.377206   80000.0      USD         80000.00
# 6 -34.925402 -57.913334       NaN      NaN              NaN
# 7 -34.601819 -58.376713  200000.0      USD        200000.00
# 8 -31.163823 -64.326000  900000.0      ARS         54841.26
# 9 -34.644414 -58.622900   76000.0      USD         76000.00
#
#    surface_total_in_m2  surface_covered_in_m2  rooms  expenses  \
# 0                  NaN                    NaN    NaN       NaN
# 1                  NaN                  185.0    5.0       NaN
# 2                  NaN                   43.0    1.0       NaN
# 3                  NaN                   38.0    1.0       NaN
# 4                  NaN                  193.0    NaN       NaN
# 5                  NaN                   47.0    3.0       NaN
# 6                  NaN                    NaN    NaN       NaN
# 7                  NaN                   20.0    NaN       NaN
# 8                  NaN                  110.0    NaN       NaN
# 9                  NaN                   50.0    2.0       NaN
#
#                                        properati_url
# 0  http://www.properati.com.ar/14mll_venta_casa_q...
# 1  http://www.properati.com.ar/14mlv_venta_casa_p...
# 2  http://www.properati.com.ar/14mm2_venta_depart...
# 3  http://www.properati.com.ar/14mm3_venta_depart...
# 4  http://www.properati.com.ar/14mn6_venta_casa_c...
# 5  http://www.properati.com.ar/14mo0_venta_depart...
# 6  http://www.properati.com.ar/14moc_venta_casa_l...
# 7  http://www.properati.com.ar/14moh_venta_local_...
# 8  http://www.properati.com.ar/14moi_venta_casa_r...
# 9  http://www.properati.com.ar/14mox_venta_depart...
