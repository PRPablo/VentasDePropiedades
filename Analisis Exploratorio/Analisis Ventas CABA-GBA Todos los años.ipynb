# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # Análisis de columnas
# ## Se hace un pequeño análisis global del dataset.

# %%
#Ante todo, empezamos a analizar la información brindada por los datasets y sus respectivas columnas.
#analisis de los ultimos 4 años
#2013
sells_07_2013 = pd.read_csv('filterdata/sells_07_2013.csv')
sells_08_2013 = pd.read_csv('filterdata/sells_08_2013.csv')
sells_09_2013 = pd.read_csv('filterdata/sells_09_2013.csv')
sells_10_2013 = pd.read_csv('filterdata/sells_10_2013.csv')
sells_11_2013 = pd.read_csv('filterdata/sells_11_2013.csv')
sells_12_2013 = pd.read_csv('filterdata/sells_12_2013.csv')
frames_2013 = [sells_07_2013, sells_08_2013, sells_09_2013,sells_10_2013, sells_11_2013, sells_12_2013]
sells_2013 = pd.concat(frames_2013)

#2014
sells_01_2014 = pd.read_csv('filterdata/sells_01_2014.csv')
sells_02_2014 = pd.read_csv('filterdata/sells_02_2014.csv')
sells_03_2014 = pd.read_csv('filterdata/sells_03_2014.csv')
sells_04_2014 = pd.read_csv('filterdata/sells_04_2014.csv')
sells_05_2014 = pd.read_csv('filterdata/sells_05_2014.csv')
sells_06_2014 = pd.read_csv('filterdata/sells_06_2014.csv')
sells_07_2014 = pd.read_csv('filterdata/sells_07_2014.csv')
sells_08_2014 = pd.read_csv('filterdata/sells_08_2014.csv')
sells_09_2014 = pd.read_csv('filterdata/sells_09_2014.csv')
sells_10_2014 = pd.read_csv('filterdata/sells_10_2014.csv')
sells_11_2014 = pd.read_csv('filterdata/sells_11_2014.csv')
sells_12_2014 = pd.read_csv('filterdata/sells_12_2014.csv')
frames_2014 = [sells_01_2014, sells_02_2014, sells_03_2014, sells_04_2014, sells_05_2014, sells_06_2014, sells_07_2014, sells_08_2014, sells_09_2014,sells_10_2014, sells_11_2014, sells_12_2014]
sells_2014 = pd.concat(frames_2014)

#2015
sells_01_2015 = pd.read_csv('filterdata/sells_01_2015.csv')
sells_02_2015 = pd.read_csv('filterdata/sells_02_2015.csv')
sells_03_2015 = pd.read_csv('filterdata/sells_03_2015.csv')
sells_04_2015 = pd.read_csv('filterdata/sells_04_2015.csv')
sells_05_2015 = pd.read_csv('filterdata/sells_05_2015.csv')
sells_06_2015 = pd.read_csv('filterdata/sells_06_2015.csv')
sells_07_2015 = pd.read_csv('filterdata/sells_07_2015.csv')
sells_08_2015 = pd.read_csv('filterdata/sells_08_2015.csv')
sells_09_2015 = pd.read_csv('filterdata/sells_09_2015.csv')
sells_10_2015 = pd.read_csv('filterdata/sells_10_2015.csv')
sells_11_2015 = pd.read_csv('filterdata/sells_11_2015.csv')
sells_12_2015 = pd.read_csv('filterdata/sells_12_2015.csv')
frames_2015 = [sells_01_2015, sells_02_2015, sells_03_2015, sells_04_2015, sells_05_2015, sells_06_2015, sells_07_2015, sells_08_2015, sells_09_2015,sells_10_2015, sells_11_2015, sells_12_2015]
sells_2015 = pd.concat(frames_2015)

#2016
sells_01_2016 = pd.read_csv('filterdata/sells_01_2016.csv')
sells_02_2016 = pd.read_csv('filterdata/sells_02_2016.csv')
sells_03_2016 = pd.read_csv('filterdata/sells_03_2016.csv')
sells_04_2016 = pd.read_csv('filterdata/sells_04_2016.csv')
sells_05_2016 = pd.read_csv('filterdata/sells_05_2016.csv')
sells_06_2016 = pd.read_csv('filterdata/sells_06_2016.csv')
sells_07_2016 = pd.read_csv('filterdata/sells_07_2016.csv')
sells_08_2016 = pd.read_csv('filterdata/sells_08_2016.csv')
sells_09_2016 = pd.read_csv('filterdata/sells_09_2016.csv')
sells_10_2016 = pd.read_csv('filterdata/sells_10_2016.csv')
sells_11_2016 = pd.read_csv('filterdata/sells_11_2016.csv')
sells_12_2016 = pd.read_csv('filterdata/sells_12_2016.csv')
frames_2016 = [sells_01_2016, sells_02_2016, sells_03_2016, sells_04_2016, sells_05_2016, sells_06_2016, sells_07_2016, sells_08_2016, sells_09_2016,sells_10_2016, sells_11_2016, sells_12_2016]
sells_2016 = pd.concat(frames_2016)

#2017
sells_01_2017 = pd.read_csv('filterdata/sells_01_2017.csv')
sells_02_2017 = pd.read_csv('filterdata/sells_02_2017.csv')
sells_03_2017 = pd.read_csv('filterdata/sells_03_2017.csv')
sells_04_2017 = pd.read_csv('filterdata/sells_04_2017.csv')
sells_05_2017 = pd.read_csv('filterdata/sells_05_2017.csv')
sells_06_2017 = pd.read_csv('filterdata/sells_06_2017.csv')
sells_07_2017 = pd.read_csv('filterdata/sells_07_2017.csv')
frames_2017 = [sells_01_2017, sells_02_2017, sells_03_2017, sells_04_2017, sells_05_2017, sells_06_2017, sells_07_2017]
sells_2017 = pd.concat(frames_2017)

#Concateno los años
frames = [sells_2013, sells_2014, sells_2015, sells_2016, sells_2017]
sells = pd.concat(frames)

# %% [markdown]
# Se eliminaron algunas columnas que a nuestro entender no agregan información relevante para el estudio.

# %%
#Vericamos las columnas restantes a analizar.
sells.columns.values
# Out:
# array(['Unnamed: 0', 'created_on', 'property_type', 'place_name',
#        'state_name', 'lat', 'lon', 'price', 'currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'rooms', 'expenses', 'properati_url'], dtype=object)

# %%
#Mirada global del dataframe resultante.
sells.head(10)
# Out:
#    Unnamed: 0  created_on property_type  place_name  \
# 0     36436.0  2013-07-01     apartment    Belgrano
# 1     36437.0  2013-07-01     apartment     Palermo
# 2     36438.0  2013-07-01     apartment     Palermo
# 3     36439.0  2013-07-01     apartment  San Isidro
# 4     36440.0  2013-07-01     apartment    Martínez
# 5     36441.0  2013-07-01         house      Beccar
# 6     36442.0  2013-07-01         house  San Isidro
# 7     36443.0  2013-07-01         house     Chauvín
# 8     36444.0  2013-07-01         house       Pilar
# 9     36445.0  2013-07-01     apartment   Balvanera
#
#                                           state_name        lat        lon  \
# 0               |Argentina|Capital Federal|Belgrano|        NaN        NaN
# 1                |Argentina|Capital Federal|Palermo|        NaN        NaN
# 2                |Argentina|Capital Federal|Palermo| -34.584075 -58.425409
# 3    |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|        NaN        NaN
# 4  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...        NaN        NaN
# 5  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...        NaN        NaN
# 6    |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|        NaN        NaN
# 7  |Argentina|Buenos Aires Costa Atlántica|Mar de... -38.020430 -57.560932
# 8   |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar| -34.425666 -58.903835
# 9              |Argentina|Capital Federal|Balvanera| -34.617081 -58.404125
#
#       price currency  price_aprox_usd  surface_total_in_m2  rooms    expenses  \
# 0  650000.0      USD         650000.0                  NaN    3.0         NaN
# 1   85000.0      USD          85000.0                  NaN    2.0         NaN
# 2   98000.0      USD          98000.0                 47.0    2.0  $ 600
# 3  120000.0      USD         120000.0                  NaN    2.0         NaN
# 4  110000.0      USD         110000.0                  NaN    2.0         NaN
# 5  320000.0      USD         320000.0                  NaN    0.0         NaN
# 6  720000.0      USD         720000.0                  NaN    0.0         NaN
# 7  330000.0      USD         330000.0                468.0    5.0         NaN
# 8  190000.0      USD         190000.0                  NaN    5.0         NaN
# 9   56900.0      USD          56900.0                 30.0    2.0         NaN
#
#                                        properati_url
# 0  http://www.properati.com.ar/85if_venta_departa...
# 1  http://www.properati.com.ar/85ig_venta_departa...
# 2  http://www.properati.com.ar/85ih_venta_departa...
# 3  http://www.properati.com.ar/85ik_venta_departa...
# 4  http://www.properati.com.ar/85im_venta_departa...
# 5  http://www.properati.com.ar/85iv_venta_casa_be...
# 6  http://www.properati.com.ar/85iw_venta_casa_sa...
# 7  http://www.properati.com.ar/85j8_venta_casa_ch...
# 8  http://www.properati.com.ar/85ja_venta_casa_pilar
# 9  http://www.properati.com.ar/85jb_venta_departa...

# %%
#Se empieza por analizar la columna donde se encuentra el lugar de la publicación.
#uso regex para buscar coincidencias por string
sells_caba = sells.loc[sells['state_name'].str.contains(r'(Capital Federal|capital federal)', na=False)]
sells_caba.count()
# Out:
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
# Unnamed: 0             194162
# created_on             194162
# property_type          194162
# place_name             194162
# state_name             194162
# lat                    176362
# lon                    176357
# price                  176531
# currency               175503
# price_aprox_usd        176529
# surface_total_in_m2    143591
# rooms                  135874
# expenses                20485
# properati_url          194162
# dtype: int64

# %%
#filtro barrio Capital Federal de caba (se analiza de forma aparte)
sells_caba = sells_caba[sells_caba['place_name']!='Capital Federal']
sells_caba.count()
# Out:
# Unnamed: 0             174889
# created_on             174889
# property_type          174889
# place_name             174889
# state_name             174889
# lat                    159579
# lon                    159574
# price                  158577
# currency               157571
# price_aprox_usd        158575
# surface_total_in_m2    131935
# rooms                  121952
# expenses                20078
# properati_url          174889
# dtype: int64

# %%
#Uso regex para buscar coincidencias por string entre diferentes zonas del Gran Buenos Aires y las agrupo.
#Se hace un count para consistencias de datos.
sells_gba = sells.loc[sells['state_name'].str.contains(r'(G.B.A|Zona Norte|Zona Sur|Zona Este|Zona Oeste)', na=False)]
sells_gba.count()
# Out:
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
# Unnamed: 0             246071
# created_on             246071
# property_type          246071
# place_name             246021
# state_name             246071
# lat                    155160
# lon                    155160
# price                  215581
# currency               213429
# price_aprox_usd        215581
# surface_total_in_m2    168387
# rooms                  111248
# expenses                11336
# properati_url          246071
# dtype: int64

# %% [markdown]
# # Se observa el enfoque en particular que tiene el dataframe.¶

# %%
#Distribución de ventas agrupadas por las zonas de Capital Federal y el Gran Buenos Aires.

ventas_en_caba = sells_caba['state_name'].value_counts()
ventas_en_gba = sells_gba['state_name'].value_counts().sum()
sizes = (ventas_en_caba,ventas_en_gba)
ventas_en_gba
nombres_de_parametros = ['Ventas en Capital Federal', 'Ventas en Gran Buenos Aires']

plt.figure(figsize=(8, 8))
plt.title('Distribucion de ventas de propiedades por zonas\n(Capital Federal y el gran Buenos Aires)', fontsize=20)
plt.pie(sizes, labels=nombres_de_parametros, autopct='%1.1f%%', startangle=1000
    , colors=['seagreen', 'coral'], explode=(0.15, 0))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-effa60edaba1> in <module>()
#      10 plt.title('Distribucion de ventas de propiedades por zonas\n(Capital Federal y el gran Buenos Aires)', fontsize=20)
#      11 plt.pie(sizes, labels=nombres_de_parametros, autopct='%1.1f%%', startangle=1000
# ---> 12     , colors=['seagreen', 'coral'], explode=(0.15, 0))
#      13 plt.show()
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, hold, data)
#    3295                      radius=radius, counterclock=counterclock,
#    3296                      wedgeprops=wedgeprops, textprops=textprops, center=center,
# -> 3297                      frame=frame, data=data)
#    3298     finally:
#    3299         ax._hold = washold
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame)
#    2573         """
#    2574
# -> 2575         x = np.asarray(x).astype(np.float32)
#    2576
#    2577         sx = float(x.sum())
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# Con este plot, se puede ver que el dataframe tiene un enfoque particular en ventas que se centra en zonas aledañas a Capital Federal.

# %% [markdown]
# # Promedios de precios relacionado con las fechas

# %%
#promedio de precios desde 2013 hasta 2017 CABA
sells_caba_date = sells_caba.loc[:,['created_on','price_aprox_usd']]
sells_caba_date_group = sells_caba_date.groupby('created_on')
sells_caba_date_group = sells_caba_date_group.mean()['price_aprox_usd']
sells_caba_date_group.plot(x='created_on' , y = 'price_aprox_usd', style='go',figsize=(14,5))
plt.show()

# %%
sells_gba_date = sells_gba.loc[:,['created_on','price_aprox_usd']]
sells_gba_date_group = sells_gba_date.groupby('created_on')
sells_gba_date_group = sells_gba_date_group.mean()['price_aprox_usd']
sells_gba_date_group.plot(x='created_on' , y = 'price_aprox_usd', style='go',figsize=(14,5))
plt.show()

# %% [markdown]
# En ambos graficos se puede apreciar como aumenta el valor minimo de los precios con el tiempo.

# %% [markdown]
# # Primeros trabajos sobre propiedades en Capital Federal.

# %%
#Obtengo del dataframe de Capital Federal las columnas 'state_name', 'place_name' y 'price_aprox_usd'.
#Muestra un random de 10 publicaciones.
sells_caba_price = sells_caba.loc[:,['state_name','place_name','price_aprox_usd']]
sells_caba_price.head(10)
# Out:
#                                            state_name     place_name  \
# 0                |Argentina|Capital Federal|Belgrano|       Belgrano
# 1                 |Argentina|Capital Federal|Palermo|        Palermo
# 2                 |Argentina|Capital Federal|Palermo|        Palermo
# 9               |Argentina|Capital Federal|Balvanera|      Balvanera
# 12              |Argentina|Capital Federal|Balvanera|      Balvanera
# 13               |Argentina|Capital Federal|Congreso|       Congreso
# 14             |Argentina|Capital Federal|Colegiales|     Colegiales
# 18              |Argentina|Capital Federal|Balvanera|      Balvanera
# 21  |Argentina|Capital Federal|Palermo|Palermo Chico|  Palermo Chico
# 22               |Argentina|Capital Federal|Belgrano|       Belgrano
#
#     price_aprox_usd
# 0          650000.0
# 1           85000.0
# 2           98000.0
# 9           56900.0
# 12          44000.0
# 13          58500.0
# 14         160000.0
# 18          80000.0
# 21          91800.0
# 22         139000.0

# %%
#Agrupo las columnas filtradas por lugar y promedio el precio de las propiedades.
sells_caba_group = sells_caba_price.groupby('place_name')
sells_caba_group.mean()
# Out:
#                        price_aprox_usd
# place_name
# Abasto                   167385.013712
# Agronomía                149331.519343
# Almagro                  140308.054562
# Balvanera                141943.116589
# Barracas                 167618.647371
# Barrio Norte             289390.768453
# Belgrano                 297142.586216
# Boca                     140119.726246
# Boedo                    165719.757880
# Caballito                163611.444377
# Catalinas                345636.363636
# Centro / Microcentro     159809.537225
# Chacarita                162442.168452
# Coghlan                  183738.725382
# Colegiales               184197.297235
# Congreso                 146357.335441
# Constitución             112528.594230
# Distrito Audiovisual     228985.805789
# Distrito Tecnológico     105476.166667
# Distrito de las Artes    109779.342895
# Flores                   149928.568428
# Floresta                 143210.134499
# Las Cañitas              280220.653456
# Liniers                  147589.060581
# Mataderos                145152.039189
# Monserrat                161918.835002
# Monte Castro             133876.851775
# Nuñez                    250106.101726
# Once                     167311.655808
# Palermo                  293450.083705
# ...                                ...
# Parque Centenario        142221.428730
# Parque Chacabuco         149096.859652
# Parque Chas              145149.085906
# Parque Patricios         130374.317040
# Paternal                 141657.932131
# Pompeya                  178360.216038
# Puerto Madero            794008.396779
# Recoleta                 382144.508322
# Retiro                   387257.105365
# Saavedra                 165593.040966
# San Cristobal            177989.485131
# San Nicolás              290598.796625
# San Telmo                175228.630264
# Tribunales               156251.586557
# Velez Sarsfield          183467.977911
# Versalles                171099.908661
# Villa Crespo             151528.705345
# Villa Devoto             194528.229414
# Villa General Mitre      158650.816699
# Villa Lugano             113185.759467
# Villa Luro               148633.968743
# Villa Ortuzar            175533.412996
# Villa Pueyrredón         142546.030293
# Villa Real               159262.330508
# Villa Riachuelo          116162.500000
# Villa Santa Rita         142574.375700
# Villa Soldati            240344.309259
# Villa Urquiza            157675.646358
# Villa del Parque         139158.049881
# Zona Portuaria           320000.000000
#
# [65 rows x 1 columns]

# %% [markdown]
# ## Cantidad de ventas de propiedades por barrios de Capital Federal.

# %%
#defino cantidad de ventas por barrio
sells_caba_group_count = sells_caba_group.count()['state_name']
sells_caba_group_count.sort_values(ascending=False)
# Out:
# place_name
# Belgrano                 17329
# Palermo                  14121
# Caballito                11589
# Barrio Norte              8138
# Villa Urquiza             7895
# Villa Crespo              7800
# Flores                    7403
# Almagro                   6638
# Recoleta                  6543
# Nuñez                     6097
# Boedo                     4678
# Balvanera                 4259
# Barracas                  3644
# San Telmo                 3626
# San Cristobal             3510
# Saavedra                  3365
# Colegiales                3355
# Palermo Chico             3226
# Villa Devoto              3024
# Puerto Madero             2882
# Floresta                  2850
# Villa del Parque          2751
# Palermo Hollywood         2700
# Mataderos                 2440
# Monserrat                 2284
# Villa Luro                2116
# Congreso                  2011
# Villa Pueyrredón          1964
# Liniers                   1887
# Palermo Soho              1683
#                          ...
# Las Cañitas               1354
# San Nicolás               1164
# Chacarita                 1109
# Retiro                    1069
# Boca                       972
# Constitución               967
# Paternal                   957
# Villa Lugano               916
# Abasto                     810
# Monte Castro               682
# Parque Centenario          682
# Villa General Mitre        546
# Villa Ortuzar              531
# Agronomía                  494
# Villa Santa Rita           419
# Velez Sarsfield            408
# Tribunales                 408
# Palermo Viejo              401
# Versalles                  396
# Parque Chas                392
# Parque Avellaneda          386
# Pompeya                    303
# Villa Real                 242
# Distrito Audiovisual        95
# Villa Soldati               61
# Distrito de las Artes       38
# Villa Riachuelo             15
# Catalinas                   13
# Distrito Tecnológico         6
# Zona Portuaria               4
# Name: state_name, dtype: int64

# %% [markdown]
# Con el conteo de ventas por barrios, se puede observar que Palermo,Belgrano y Caballito son las zonas con más ventas de Capital Federal. Por otro lado, Las zonas como Villa Soldati, Villa Riachuelo y Villa Real son los barrios con menos ventas.

# %%
#Para tener consistencias en los datos, se decide filtrar los contenidos por un mínimo de ventas por barrio para empezar 
#a analizar.
#como hay min 5 cantidad de ventas, filtro por >= 15
sells_caba_group = sells_caba_price.groupby('place_name').agg([np.mean,np.size])
sells_caba_group = sells_caba_group.loc[sells_caba_group[('price_aprox_usd','size')]>=15,:]   
sells_caba_group.head()
# Out:
#            price_aprox_usd
#                       mean    size
# place_name
# Abasto       167385.013712   810.0
# Agronomía    149331.519343   494.0
# Almagro      140308.054562  6638.0
# Balvanera    141943.116589  4259.0
# Barracas     167618.647371  3644.0

# %% [markdown]
# # Precio en dólares promedio de una propiedad por barrio en Capital Federal.
#
# #### Precios promedio más altos de Capital Federal.

# %%
#top 10 CABA promedio de precios en Capital Federal.

sells_caba_sort_desc = sells_caba_group.sort_values(('price_aprox_usd','mean'), ascending=False)
sells_caba_sort_desc.head(10)
# Out:
#               price_aprox_usd
#                          mean     size
# place_name
# Puerto Madero   794008.396779   2882.0
# Palermo Chico   438651.972496   3226.0
# Retiro          387257.105365   1069.0
# Recoleta        382144.508322   6543.0
# Belgrano        297142.586216  17329.0
# Palermo         293450.083705  14121.0
# San Nicolás     290598.796625   1164.0
# Barrio Norte    289390.768453   8138.0
# Las Cañitas     280220.653456   1354.0
# Nuñez           250106.101726   6097.0

# %% [markdown]
# Claramente, las zonas de Palermo Chico y Puerto Madero son las zonas donde el precio en promedio, dominan en Capital Federal como las zonas promedios más caras de Capital Federal.

# %%
#Visualizacion de precios promedios de los 10 barrios con mayor valor.

plt.ylabel = "1"
ax = sells_caba_sort_desc[('price_aprox_usd','mean')][0:10].plot(title = "Top 10 de precio promedio de ventas en Capital Federal en USD",kind='bar',figsize=(14,4))
ax.set_ylabel('Precio en USD')
ax.set_xlabel('Barrios de Capital Federal')
plt.show()

# %% [markdown]
# Con el plot, se ve la gran diferencia de precios promedio entre los barrios de Palermo Chico y Puerto Madero con respecto a los demás barrios que integran el top10 de las zonas más caras.

# %% [markdown]
# ####  Precios promedio más bajos de Capital Federal.

# %%
#top 10 CABA promedio de precios más bajos en Capital Federal por barrio.

sells_caba_sort_asc = sells_caba_group.sort_values(('price_aprox_usd','mean'), ascending=True)
sells_caba_sort_asc.head(10)
# Out:
#                       price_aprox_usd
#                                  mean    size
# place_name
# Distrito de las Artes   109779.342895    38.0
# Constitución            112528.594230   967.0
# Villa Lugano            113185.759467   916.0
# Villa Riachuelo         116162.500000    15.0
# Parque Patricios        130374.317040  1469.0
# Monte Castro            133876.851775   682.0
# Villa del Parque        139158.049881  2751.0
# Boca                    140119.726246   972.0
# Almagro                 140308.054562  6638.0
# Parque Avellaneda       141574.397562   386.0

# %%
#Visualizacion de precios promedios de los 10 barrios con menor valor.

plt.ylabel = "1"
ax = sells_caba_sort_asc[('price_aprox_usd','mean')][0:10].plot(title = "Top 10 de las zonas con menor precio promedio de Capital Federal en USD",kind='bar',figsize=(14,4))
ax.set_ylabel('Precio en USD')
ax.set_xlabel('Barrios de Capital Federal')
plt.show()

# %% [markdown]
# Así como Puerto Madero y Palermo Chico mostraban una diferencia de precios muy marcada con los inmediatos seguidores, en este plot, se puede observar que Constitucion se encuentra como la zona de menor precio promedio de Capital Federal, seguidas de Villa Lugano y Villa Riachuelo.

# %%
# Histograma de cantidad de promedio de precios y cantidad de ventas
ax = sells_caba_group[('price_aprox_usd','mean')].hist(figsize=(25,10));
ax.set_ylabel('Cantidad de propiedades',fontsize=20)
ax.set_xlabel('Rango de precios',fontsize=20)
ax.set_title("Distribución promedio de ventas en Capital Federal",fontsize = 25)
plt.show()

# %%
#concentracion de precios por tipo de propiedades
sells_caba_property = sells_caba.loc[:,['property_type','price_aprox_usd']]
sells_caba_property = sells_caba_property[np.isfinite(sells_caba_property['price_aprox_usd'])]
sells_caba_property['sub_index'] = sells_caba_property.groupby('property_type').cumcount() + 1
sells_caba_property = pd.pivot_table(sells_caba_property,index='sub_index',columns='property_type',values='price_aprox_usd')

sells_caba_property.plot.box(figsize=(15,5))

# %%
#distribucion de precios por tipo de propiedad en CABA
sells_caba_distr = sells_caba.sort_values(by='price_aprox_usd', ascending=True)
sells_caba_distr = sells_caba_distr.groupby('property_type')
sells_caba_distr.plot(x='property_type' , y='price_aprox_usd', style='go',figsize=(14,5))
plt.show()

# %% [markdown]
# ### Primeros trabajos sobre propiedades en Capital Federal.

# %%
#cantidad ventas de tipo de propiedades en CABA
sells_caba_property = sells_caba.loc[:,['property_type','place_name']]
sells_caba_property.head(10)
# Out:
#    property_type     place_name
# 0      apartment       Belgrano
# 1      apartment        Palermo
# 2      apartment        Palermo
# 9      apartment      Balvanera
# 12     apartment      Balvanera
# 13     apartment       Congreso
# 14     apartment     Colegiales
# 18            PH      Balvanera
# 21     apartment  Palermo Chico
# 22     apartment       Belgrano

# %%
sells_caba_property_group = sells_caba_property.groupby('property_type').agg([np.size])
sells_caba_property_group_count = sells_caba_property_group.sort_values(('place_name','size'), ascending=False)
sells_caba_property_group_count.head(10)
# Out:
#               place_name
#                     size
# property_type
# apartment         149878
# PH                 10962
# house               9726
# store               4323

# %%
#cantidad de ventas por tipo de propiedades en CABA
sells_caba_property_group_count[0:10].plot(title = "Cantidad de ventas por tipo de propiedades",kind='bar',figsize=(14,4))

# %%
#proporciones de tipos de propiedades distribuidas en distintos barrios
sells_caba_compare = sells_caba_property.groupby(['property_type', 'place_name'])['property_type'].count().unstack('place_name').fillna(0)
sells_caba_compare.plot(kind='bar', stacked=True)

# %% [markdown]
# ### Primeros trabajos sobre propiedades en Gran Buenos Aires.

# %%
sells_gba_price = sells_gba.loc[:,['state_name','place_name','price_aprox_usd']]
sells_gba_price.head(10)
# Out:
#                                            state_name       place_name  \
# 3     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|       San Isidro
# 4   |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...         Martínez
# 5   |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...           Beccar
# 6     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|       San Isidro
# 8    |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|            Pilar
# 15  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...         Martínez
# 16         |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|            Tigre
# 17         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|            Pilar
# 20  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...         Martínez
# 23  |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...  Tres de Febrero
#
#     price_aprox_usd
# 3          120000.0
# 4          110000.0
# 5          320000.0
# 6          720000.0
# 8          190000.0
# 15         105000.0
# 16          90000.0
# 17         190000.0
# 20         110000.0
# 23          51000.0

# %%
sells_gba_group = sells_gba_price.groupby("place_name")
sells_gba_group.head()
# Out:
#                                               state_name  \
# 3        |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|
# 4      |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...
# 5      |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...
# 6        |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|
# 8       |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|
# 15     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...
# 16            |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|
# 17            |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|
# 20     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...
# 23     |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...
# 24     |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...
# 25      |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|
# 28     |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|Lanús ...
# 29     |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|Lanús ...
# 31     |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...
# 36     |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|Lanús ...
# 37     |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...
# 40     |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...
# 43            |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|
# 45            |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|
# 46            |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|
# 49     |Argentina|Bs.As. G.B.A. Zona Sur|Quilmes|Bernal|
# 52     |Argentina|Bs.As. G.B.A. Zona Sur|Quilmes|Bernal|
# 53     |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|...
# 55     |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|Lanús ...
# 60     |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...
# 61            |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|
# 65      |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Morón|
# 66     |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|Be...
# 67     |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|Be...
# ...                                                  ...
# 19624                           Bs.As. G.B.A. Zona Norte
# 21537                             Bs.As. G.B.A. Zona Sur
# 21563                             Bs.As. G.B.A. Zona Sur
# 23880                             Bs.As. G.B.A. Zona Sur
# 26144                             Bs.As. G.B.A. Zona Sur
# 26318                             Bs.As. G.B.A. Zona Sur
# 29315                           Bs.As. G.B.A. Zona Norte
# 30196                             Bs.As. G.B.A. Zona Sur
# 32538                             Bs.As. G.B.A. Zona Sur
# 33889                             Bs.As. G.B.A. Zona Sur
# 35238                             Bs.As. G.B.A. Zona Sur
# 36880                             Bs.As. G.B.A. Zona Sur
# 45690                           Bs.As. G.B.A. Zona Oeste
# 46023                           Bs.As. G.B.A. Zona Norte
# 46227                           Bs.As. G.B.A. Zona Norte
# 46636                             Bs.As. G.B.A. Zona Sur
# 46660                             Bs.As. G.B.A. Zona Sur
# 46736                             Bs.As. G.B.A. Zona Sur
# 48154                           Bs.As. G.B.A. Zona Norte
# 48166                           Bs.As. G.B.A. Zona Norte
# 48184                           Bs.As. G.B.A. Zona Norte
# 48189                           Bs.As. G.B.A. Zona Norte
# 49316                             Bs.As. G.B.A. Zona Sur
# 49436                           Bs.As. G.B.A. Zona Norte
# 51458                           Bs.As. G.B.A. Zona Norte
# 55581                           Bs.As. G.B.A. Zona Oeste
# 56976                           Bs.As. G.B.A. Zona Norte
# 58811                           Bs.As. G.B.A. Zona Norte
# 59675                           Bs.As. G.B.A. Zona Norte
# 61721                           Bs.As. G.B.A. Zona Norte
#
#                             place_name  price_aprox_usd
# 3                           San Isidro        120000.00
# 4                             Martínez        110000.00
# 5                               Beccar        320000.00
# 6                           San Isidro        720000.00
# 8                                Pilar        190000.00
# 15                            Martínez        105000.00
# 16                               Tigre         90000.00
# 17                               Pilar        190000.00
# 20                            Martínez        110000.00
# 23                     Tres de Febrero         51000.00
# 24                       Vicente López              NaN
# 25                               Pilar        280000.00
# 28                         Lanús Oeste         80000.00
# 29                         Lanús Oeste         72924.53
# 31                            La Plata              NaN
# 36                         Lanús Oeste        120000.00
# 37                            La Plata              NaN
# 40                            La Plata              NaN
# 43                               Pilar              NaN
# 45                               Pilar              NaN
# 46                               Tigre        800000.00
# 49                              Bernal        180000.00
# 52                              Bernal         98000.00
# 53                           Ituzaingó        145849.07
# 55                         Lanús Oeste        140000.00
# 60               Gregorio de Laferrere         59835.51
# 61                               Tigre        275000.00
# 65                               Morón              NaN
# 66                    Belén de Escobar        114061.45
# 67                    Belén de Escobar              NaN
# ...                                ...              ...
# 19624                     La Herradura        268000.00
# 21537                         San José        140000.00
# 21563                         San José        120000.00
# 23880                       9 de Abril        300000.00
# 26144                         San José        130000.00
# 26318                         San José        145000.00
# 29315                 Virasoro Village        670000.00
# 30196                       9 de Abril        400000.00
# 32538                       Mi Refugio        200000.00
# 33889                       Terralagos              NaN
# 35238                       Terralagos        330000.00
# 36880                   José Hernández        135000.00
# 45690                 Prados del Oeste        250000.00
# 46023                       Hindu Club        380000.00
# 46227                  El Viejo Vivero        350000.00
# 46636                     Arturo Seguí         65000.00
# 46660                     Arturo Seguí        150000.00
# 46736                     Arturo Seguí        110000.00
# 48154                          Manzone        184264.00
# 48166                          Manzone        190854.00
# 48184                          Manzone        343765.00
# 48189                          Manzone        343765.00
# 49316                 Villa Centenario        126000.00
# 49436                 San Isidro Chico       1000000.00
# 51458                 San Isidro Chico       1150000.00
# 55581       Barrio Privado El Resuello        220000.00
# 56976      Barrio Cerrado "El Estribo"        415000.00
# 58811   Barrio Cerrado Lagos del Norte        740000.00
# 59675    Barrio Cerrado "La Escondida"        769000.00
# 61721  Barrio Cerrado "Las Araucarias"        244800.00
#
# [2530 rows x 3 columns]

# %% [markdown]
# #### Cantidad de ventas de propiedades por barrio en el Gran Buenos Aires.

# %%
#defino cantidad de ventas por barrio
sells_gba_group_count = sells_gba_group.count()['state_name']
sells_gba_group_count.sort_values(ascending=False)
# Out:
# place_name
# Tigre                                 16569
# Nordelta                              15686
# Pilar                                 14088
# La Plata                              11285
# Morón                                  8382
# Olivos                                 8107
# Ramos Mejía                            7245
# La Matanza                             7075
# San Isidro                             6946
# Ituzaingó                              6407
# Vicente López                          6073
# Benavidez                              5878
# Martínez                               5432
# Bs.As. G.B.A. Zona Norte               4764
# San Fernando                           4274
# Castelar                               3736
# San Miguel                             3730
# Escobar                                3518
# General San Martín                     3510
# Quilmes                                3491
# Lomas de Zamora                        3397
# Caseros                                3275
# Haedo                                  2933
# Florida                                2916
# Lanús                                  2907
# Moreno                                 2626
# San Martín                             2601
# Villa Ballester                        2330
# Beccar                                 2319
# Victoria                               2303
#                                       ...
# Barrio San Benito                         1
# Villa Chacabuco                           1
# Barrio El Golf - Nordelta                 1
# Barrio Cerrado "La Rinconada"             1
# Barrio Cerrado "Los Eucaliptus"           1
# Barrio Cerrado "Los Laureles"             1
# Barrio Cerrado "La Merced"                1
# Barrio Cerrado "Pilar Privado"            1
# Barrio Cerrado "La Laguna"                1
# Barrio Cerrado "La Escondida"             1
# Terrazas de Ayres                         1
# Barrio Cerrado "SpringDale"               1
# Barrio Cerrado "La Damasia"               1
# Barrio Cerrado "Villa Rosa"               1
# Barrio Cerrado Los Abedules               1
# Barrio La Alameda - Nordelta              1
# Barrio cerrado Camino Real                1
# Santa Rosa                                1
# Barrio La Isla - Nordelta                 1
# Barrio Las Glorietas - Nordelta           1
# Barrio Los Alisos - Nordelta              1
# Barrio Melazzi                            1
# Barrio Cerrado "Bella Vista Chico"        1
# Barrio Privado Lagos de Canning           1
# Barrio Privado María Eugenia              1
# Barrio Privado Santo Domingo              1
# Villa Brown                               1
# Pereyra                                   1
# Barrio Vistas                             1
# Área de Promoción El Triángulo            1
# Name: state_name, dtype: int64

# %% [markdown]
# Como primera observación realizada, Nordelta, Tigre, La Plata y Pilar dominan ampliamante el sector de ventas de las zonas de Gran Capital, y su vez, el dataframe nos informa de muchas ventas unitarias de diferentes barrios.

# %%
#como hay min 1 cantidad de ventas, filtro por >= 50
sells_gba_group = sells_gba_price.groupby('place_name').agg([np.mean,np.size])
sells_gba_group = sells_gba_group.loc[sells_gba_group[('price_aprox_usd','size')]>=50,:]   
sells_gba_group.head(100)
# Out:
#                                      price_aprox_usd
#                                                 mean    size
# place_name
# Abril Club de Campo                    790714.285714    84.0
# Acacias Blancas                        225733.333333   105.0
# Acassuso                               554679.109819  1674.0
# Adrogué                                260529.157986  1744.0
# Aldo Bonzi                             125392.857143    91.0
# Almirante Brown                        228247.089886   237.0
# Avellaneda                             133540.833248  1153.0
# Banfield                               194895.042046  2252.0
# Barrio Ceibos                          207942.307692    55.0
# Barrio El Golf                         518095.336610   119.0
# Barrio La Alameda                      425759.493671    79.0
# Barrio Los Alisos                      368088.615726   362.0
# Barrio Los Castores                    861498.412698    64.0
# Barrio Los Jazmines - Pilar del Este   188902.352941    87.0
# Barrio Los Lagos                       569449.563889   108.0
# Barrio Parque General San Martin       107180.814426    64.0
# Barrio San Agustin                     271027.383562    73.0
# Barrio San Francisco                   288712.960269   186.0
# Barrio San Gabriel                     329882.352941   172.0
# Barrio San Isidro Labrador             365067.030977   217.0
# Barrio San Matías                      225314.450000    52.0
# Barrio Santa Clara                     362823.529412    51.0
# Barrio Santa Teresa                    306125.054357   140.0
# BarrioPortezuelo                       220210.887562   161.0
# Beccar                                 314147.837820  2319.0
# Bella Vista                            200956.888553   960.0
# Belén de Escobar                       182494.916789   882.0
# Benavidez                              349364.883349  5878.0
# Berazategui                            306125.275188  1259.0
# Bermudas Country Club                  153197.827143    70.0
# ...                                              ...     ...
# Florida                                254297.623307  2916.0
# Florida Oeste                          171022.569782   412.0
# Francisco Alvarez                      201406.888171   242.0
# Garín                                  225561.168941   372.0
# General Pacheco                        278635.830000   458.0
# General Rodríguez                      234741.715714   423.0
# General San Martín                     142967.693868  3510.0
# Gerli                                  137071.345912   140.0
# Glew                                   201021.602487   195.0
# González Catán                          89203.093333    64.0
# Grand Bourg                            134008.559085   145.0
# Guernica                               226377.782629   219.0
# Gutierrez                              232365.484231    59.0
# Haedo                                  137190.042065  2933.0
# Haras María Victoria                   221941.666667    62.0
# Haras Santa Maria                      280547.802997   328.0
# Haras del Pilar - Las Praderas 1 y 2   397036.000000    50.0
# Haras del Sur IV                        88774.409091   211.0
# Highland Park Country Club             648387.096774   101.0
# Hurlingham                             149588.846795   943.0
# Ingeniero Adolfo Sourdeaux             116973.684211    57.0
# Ingeniero Juan Allan                    49340.698406    69.0
# Ingeniero Pablo Nogués                 259405.293020   154.0
# Isidro Casanova                        136985.839459   291.0
# Ituzaingó                              158699.943367  6407.0
# Jose Leon Suarez                       102343.460671   325.0
# Jose Marmol                            169565.857032   316.0
# José C Paz                              97252.183696   369.0
# La Comarca                             302261.658818   204.0
# La Lomada de Pilar                     600571.428571    75.0
#
# [100 rows x 2 columns]

# %%
#top 10 GBA promedio
sells_gba_sort_desc = sells_gba_group.sort_values(('price_aprox_usd','mean'), ascending=False)
sells_gba_sort_desc.head(10)
# Out:
#                              price_aprox_usd
#                                         mean   size
# place_name
# El Talar de Pacheco            928460.674157   95.0
# Barrio Los Castores            861498.412698   64.0
# Abril Club de Campo            790714.285714   84.0
# Santa Barbara Barrio Cerrado   681265.760870  193.0
# Country Saint Thomas           676794.520548   87.0
# Country San Jorge Village      650119.565217  105.0
# Highland Park Country Club     648387.096774  101.0
# Mayling Club de Campo          617981.651376  116.0
# Loma Hermosa                   614444.183623   99.0
# La Lomada de Pilar             600571.428571   75.0

# %%
#top 10 GBA promedio
# %matplotlib inline

plt.figure()
plt.ylabel = "1"
ax = sells_gba_sort_desc[('price_aprox_usd','mean')][0:10].plot(title = "Top 10 de los precios promedios más caros en localidades del Gran Bueno Aires",kind='bar',figsize=(14,4))
ax.set_ylabel('Precio en USD')
ax.set_xlabel('Localidades del Gran Buenos Aires')
plt.show()

# %%
#top 10 GBA promedio mas bajos
sells_gba_sort_asc = sells_gba_group.sort_values(('price_aprox_usd','mean'), ascending=True)
sells_gba_sort_asc.head(10)
# Out:
#                      price_aprox_usd
#                                 mean   size
# place_name
# Ingeniero Juan Allan    49340.698406   69.0
# Villa Elvira            71965.103913  107.0
# Virrey del Pino         74517.440194  115.0
# Libertad                79857.147891  162.0
# Claypole                81847.975536   59.0
# Villa Libertad          83631.232532   87.0
# Villa Celina            87997.181190   58.0
# Haras del Sur IV        88774.409091  211.0
# Los Hornos              88802.065591  152.0
# González Catán          89203.093333   64.0

# %%
#top 10 GBA promedio mas bajos
plt.figure()
plt.ylabel = "1"
ax = sells_gba_sort_asc[('price_aprox_usd','mean')][0:10].plot(title = "Top 10 de los precios promedios más baratos en localidades en el Gran Bueno Aires",kind='bar',figsize=(14,4))
ax.set_ylabel('Precio en USD')
ax.set_xlabel('Localidades del Gran Buenos Aires')

plt.show()

# %%
# Histograma de cantidad de promedio de precios y cantidad de ventas
ax = sells_gba_group[('price_aprox_usd','mean')].hist(figsize=(25,10));
ax.set_ylabel('Cantidad de propiedades',fontsize=20)
ax.set_xlabel('Rango de precios',fontsize=20)
ax.set_title("Distribución promedio de ventas en GBA",fontsize = 25)
plt.show()

# %%
#concentracion de promedio precios por tipos de propiedades
sells_gba_property = sells_gba.loc[:,['property_type','price_aprox_usd']]
sells_gba_property = sells_gba_property[np.isfinite(sells_gba_property['price_aprox_usd'])]
sells_gba_property['sub_index'] = sells_gba_property.groupby('property_type').cumcount() + 1
sells_gba_property = pd.pivot_table(sells_gba_property,index='sub_index',columns='property_type',values='price_aprox_usd')

sells_gba_property.plot.box(figsize=(15,5))

# %%
#cantidad de ventas por tipo de propiedades en GBA
sells_gba_property_group = sells_gba_property.groupby('property_type').agg([np.size])
sells_gba_property_group_count = sells_gba_property_group.sort_values(('place_name','size'), ascending=False)
ax = sells_gba_property_group_count[('place_name','size')][0:10].plot(title = "Distribución de ventas por tipo en Gran Buenos Aires",kind='bar',figsize=(14,4))
ax.set_ylabel('Numero de ventas')
ax.set_xlabel('Tipos de propiedades')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'property_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-d0a5ac68c146> in <module>()
#       1 #cantidad de ventas por tipo de propiedades en GBA
# ----> 2 sells_gba_property_group = sells_gba_property.groupby('property_type').agg([np.size])
#       3 sells_gba_property_group_count = sells_gba_property_group.sort_values(('place_name','size'), ascending=False)
#       4 ax = sells_gba_property_group_count[('place_name','size')][0:10].plot(title = "Distribución de ventas por tipo en Gran Buenos Aires",kind='bar',figsize=(14,4))
#       5 ax.set_ylabel('Numero de ventas')
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3991                        **kwargs)
#    3992
#    3993     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1509         raise TypeError('invalid type: %s' % type(obj))
#    1510
# -> 1511     return klass(obj, by, **kwds)
#    1512
#    1513
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     368                                                     level=level,
#     369                                                     sort=sort,
# --> 370                                                     mutated=self.mutated)
#     371
#     372         self.obj = obj
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2460
#    2461         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2462             in_axis, name, gpr = True, gpr, obj[gpr]
#    2463             exclusions.append(name)
#    2464         elif isinstance(gpr, Grouper) and gpr.key is not None:
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'property_type'

# %%
#distribucion de precios por tipo de propiedad en GBA - 
sells_gba_distr = sells_gba.sort_values(by='price_aprox_usd', ascending=True)
sells_gba_distr = sells_gba_distr.groupby('property_type')
sells_gba_distr.plot(x='property_type' , y='price_aprox_usd', style='go',figsize=(14,5))
plt.show()

# %%
#proporciones de tipos de propiedades distribuidas en distintas localidades
sells_gba_compare = sells_gba_property.groupby(['property_type', 'place_name'])['property_type'].count().unstack('place_name').fillna(0)
sells_gba_compare.plot(kind='bar', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'property_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-21c2db550916> in <module>()
#       1 #proporciones de tipos de propiedades distribuidas en distintas localidades
# ----> 2 sells_gba_compare = sells_gba_property.groupby(['property_type', 'place_name'])['property_type'].count().unstack('place_name').fillna(0)
#       3 sells_gba_compare.plot(kind='bar', stacked=True)
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3991                        **kwargs)
#    3992
#    3993     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1509         raise TypeError('invalid type: %s' % type(obj))
#    1510
# -> 1511     return klass(obj, by, **kwds)
#    1512
#    1513
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     368                                                     level=level,
#     369                                                     sort=sort,
# --> 370                                                     mutated=self.mutated)
#     371
#     372         self.obj = obj
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2460
#    2461         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2462             in_axis, name, gpr = True, gpr, obj[gpr]
#    2463             exclusions.append(name)
#    2464         elif isinstance(gpr, Grouper) and gpr.key is not None:
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'property_type'

# %% [markdown]
# ## Promedio cantidad de habitaciones

# %%
#Cantidad promedio de habitaciones por propiedad en ventas de CABA ordenada de mayor a menor.
sells_caba_rooms_place_name = sells_caba.loc[:,['place_name','rooms']]
sells_caba_rooms_place_name = sells_caba_rooms_place_name[np.isfinite(sells_caba_rooms_place_name['rooms'])]
sells_caba_rooms = sells_caba_rooms_place_name.groupby('place_name').agg([np.mean,np.size])
sells_caba_rooms = sells_caba_rooms.loc[sells_caba_rooms[('rooms','size')]>=5,:].rename(columns={'mean': 'promedio_de_habitacion'})
sells_caba_rooms.sort_values(('rooms','promedio_de_habitacion'), ascending=False).round({('rooms','promedio_de_habitacion'):2})
# Out:
#                                        rooms
#                       promedio_de_habitacion     size
# place_name
# Catalinas                               3.50      6.0
# Retiro                                  3.41    686.0
# Recoleta                                3.33   4796.0
# Villa Soldati                           3.31     51.0
# Pompeya                                 3.18    191.0
# Villa Riachuelo                         3.14      7.0
# Versalles                               3.12    224.0
# Villa Lugano                            3.11    641.0
# Once                                    3.05   1024.0
# Palermo Chico                           3.02   2578.0
# Barrio Norte                            3.01   6143.0
# Parque Avellaneda                       2.89    279.0
# Puerto Madero                           2.89   1925.0
# Mataderos                               2.82   1664.0
# Villa Real                              2.78    161.0
# Paternal                                2.76    659.0
# Floresta                                2.74   1870.0
# Belgrano                                2.72  12054.0
# Villa Devoto                            2.68   2074.0
# Distrito de las Artes                   2.68     31.0
# Parque Patricios                        2.67   1026.0
# Tribunales                              2.63    237.0
# Congreso                                2.61   1438.0
# Boca                                    2.59    733.0
# Villa Luro                              2.58   1322.0
# Liniers                                 2.58   1212.0
# Palermo                                 2.56   9501.0
# Las Cañitas                             2.55   1058.0
# Caballito                               2.54   7480.0
# Flores                                  2.51   5084.0
# ...                                      ...      ...
# Parque Chacabuco                        2.44   1068.0
# Villa Santa Rita                        2.44    301.0
# Almagro                                 2.40   4863.0
# Villa del Parque                        2.40   1780.0
# Monte Castro                            2.40    447.0
# Palermo Viejo                           2.40    176.0
# Nuñez                                   2.38   4447.0
# Centro / Microcentro                    2.37    920.0
# Saavedra                                2.33   2197.0
# Coghlan                                 2.32    994.0
# Velez Sarsfield                         2.32    286.0
# San Nicolás                             2.32    701.0
# Chacarita                               2.32    772.0
# Colegiales                              2.26   2776.0
# San Telmo                               2.26   2193.0
# Villa Urquiza                           2.24   5429.0
# Villa Ortuzar                           2.24    375.0
# Villa Crespo                            2.22   5210.0
# Abasto                                  2.22    522.0
# Distrito Tecnológico                    2.17      6.0
# Constitución                            2.13    705.0
# Villa Pueyrredón                        2.13   1484.0
# Agronomía                               2.12    400.0
# Monserrat                               2.05   1672.0
# Palermo Hollywood                       2.02   1805.0
# Palermo Soho                            2.01   1035.0
# San Cristobal                           1.97   2334.0
# Parque Chas                             1.78    332.0
# Distrito Audiovisual                    1.63     90.0
# Boedo                                   1.61   3574.0
#
# [64 rows x 2 columns]

# %%
#Cantidad promedio de habitaciones por propiedad en ventas de GBA ordenada de mayor a menor.
sells_gba_rooms_place_name = sells_gba.loc[:,['place_name','rooms']]
sells_gba_rooms_place_name = sells_gba_rooms_place_name[np.isfinite(sells_gba_rooms_place_name['rooms'])]
sells_gba_rooms = sells_gba_rooms_place_name.groupby('place_name').agg([np.mean,np.size])
sells_gba_rooms = sells_gba_rooms.loc[sells_gba_rooms[('rooms','size')]>=15,:].rename(columns={'mean': 'promedio_de_habitacion'})
#El valor 15, corresponde a que tomo a partir de 15 ventas de propiedades por barrio para tener en cuenta en el promedio.
sells_gba_rooms.sort_values(('rooms','promedio_de_habitacion'), ascending=False).round({('rooms','promedio_de_habitacion'):2})
# Out:
#                                                       rooms
#                                      promedio_de_habitacion    size
# place_name
# La Lomada de Pilar                                     6.13    30.0
# El Encuentro                                           6.05    21.0
# Barrio Privado "Ayres de Pilar"                        5.89    27.0
# San Diego Country Club                                 5.88    17.0
# Highland Park Country Club                             5.84    25.0
# Barrio La Isla                                         5.61    18.0
# Abril Club de Campo                                    5.29    35.0
# Mayling Club de Campo                                  5.23    35.0
# El Talar de Pacheco                                    5.19    21.0
# Country Club Aranjuez                                  5.05    20.0
# Los Lagartos Country Club                              4.97    39.0
# Club de Campo Pueyrredón                               4.96    25.0
# Barrio San Gabriel                                     4.95    22.0
# Barrio San Isidro Labrador                             4.93    43.0
# Pilar del Lago                                         4.91    22.0
# Talar del Lago 1                                       4.79    24.0
# Fincas del Lago                                        4.68    19.0
# Country Banco Provincia                                4.67    15.0
# Haras del Pilar - Las Praderas 1 y 2                   4.66    29.0
# Estancias del Pilar                                    4.65    43.0
# Boat Center Barrio Cerrado                             4.64    25.0
# Acacias Blancas                                        4.64    36.0
# Barrio Los Lagos                                       4.63    19.0
# Olivos Golf Club                                       4.63    46.0
# Barrio Alamo Alto                                      4.62    21.0
# Haras Santa Maria                                      4.57   125.0
# Septiembre                                             4.57    37.0
# La Comarca                                             4.50    46.0
# Parque Leloir                                          4.43    65.0
# Barrio La Alameda                                      4.42    24.0
# ...                                                     ...     ...
# Caseros                                                2.55  1879.0
# San Fernando                                           2.54  1768.0
# Marinas Golf Barrio Cerrado                            2.53    36.0
# Lanús Oeste                                            2.52   985.0
# General San Martín                                     2.51  3045.0
# Santos Lugares                                         2.50   389.0
# La Madrugada                                           2.50    18.0
# Vila Vela Terrazas al Lago                             2.50    16.0
# Remedios de Escalada                                   2.48   361.0
# GreenVille Polo & Resort                               2.44    25.0
# Barrio Privado Puerto Trinidad                         2.38    16.0
# San Martín                                             2.37   918.0
# Tres de Febrero                                        2.36  1983.0
# Islas del Canal                                        2.35    17.0
# Sáenz Peña                                             2.34   392.0
# Muñiz                                                  2.33   232.0
# BarrioPortezuelo                                       2.32   108.0
# Crucecita                                              2.31    16.0
# Piñeiro                                                2.26    34.0
# Enyoi                                                  2.25    20.0
# Villa Tesei                                            2.25    89.0
# San Miguel                                             2.24  1321.0
# Haras del Sur IV                                       2.22   204.0
# Bermudas Country Club                                  2.22    60.0
# Rincón de la Costa                                     2.18   147.0
# Morón                                                  2.10  5234.0
# La Matanza                                             2.09  6516.0
# Ingeniero Juan Allan                                   2.05    38.0
# Derqui                                                 1.96    28.0
# La Lonja                                               1.86    21.0
#
# [242 rows x 2 columns]

# %% [markdown]
# ## Concurrencia

# %%
#Cantidad de propiedades dolarizadas por barrio.
sells_caba_por_barrio = sells_caba.loc[:,['place_name','currency']]
sells_caba_por_barrio_con_precio_dolar = sells_caba_por_barrio[sells_caba_por_barrio['currency'] == 'USD'].groupby('place_name').count()
sells_caba_por_barrio_con_precio_dolar = sells_caba_por_barrio_con_precio_dolar.rename(columns={'currency': 'numero_propiedades_con_moneda_dolar'})
sells_caba_por_barrio_con_precio_dolar.sort_values(('numero_propiedades_con_moneda_dolar'),ascending=False).head()
# Out:
#               numero_propiedades_con_moneda_dolar
# place_name
# Belgrano                                    14552
# Palermo                                     11820
# Caballito                                   10001
# Barrio Norte                                 7250
# Villa Crespo                                 6479

# %%
#Cantidad de propiedades pesificadas por barrio.
sells_caba_por_barrio_con_precio_pesos = sells_caba_por_barrio[sells_caba_por_barrio['currency'] == 'ARS'].groupby('place_name').count()
sells_caba_por_barrio_con_precio_pesos = sells_caba_por_barrio_con_precio_pesos.rename(columns={'currency': 'numero_propiedades_con_moneda_pesos'})
sells_caba_por_barrio_con_precio_pesos.sort_values(('numero_propiedades_con_moneda_pesos'),ascending=False).head()
# Out:
#                numero_propiedades_con_moneda_pesos
# place_name
# Boedo                                         1932
# San Cristobal                                 1084
# Barracas                                       875
# Villa Urquiza                                  836
# San Telmo                                      768

# %%
#Cantidas de propiedades dolarizadas según su tipo.
sells_caba_por_barrio = sells_caba.loc[:,['property_type','currency']]
sells_caba_por_barrio_con_precio_dolar = sells_caba_por_barrio[sells_caba_por_barrio['currency'] == 'USD'].groupby('property_type').count()
sells_caba_por_barrio_con_precio_dolar = sells_caba_por_barrio_con_precio_dolar.rename(columns={'currency': 'propiedad_en_moneda_dolar'})
sells_caba_por_barrio_con_precio_dolar.sort_values(('propiedad_en_moneda_dolar'),ascending=False).head()
# Out:
#                propiedad_en_moneda_dolar
# property_type
# apartment                         121917
# PH                                 10352
# house                               8340
# store                               3512

# %%
#Cantidad de propiedades pesificadas según su tipo.
sells_caba_por_barrio = sells_caba.loc[:,['property_type','currency']]
sells_caba_por_barrio_con_precio_pesos = sells_caba_por_barrio[sells_caba_por_barrio['currency'] == 'ARS'].groupby('property_type').count()
sells_caba_por_barrio_con_precio_pesos = sells_caba_por_barrio_con_precio_pesos.rename(columns={'currency': 'propiedad_en_moneda_pesos'})
sells_caba_por_barrio_con_precio_pesos.sort_values(('propiedad_en_moneda_pesos'),ascending=False).head()
# Out:
#                propiedad_en_moneda_pesos
# property_type
# apartment                          13146
# store                                151
# PH                                    87
# house                                 65

# %% [markdown]
# ## surface m2

# %%
#Distribucion de m2 por barrio (top10)
sells_caba_agrupada_por_sup_y_barrio = sells_caba.loc[:,['place_name','surface_total_in_m2']]
sells_caba_agrupada_por_sup_y_barrio.groupby('place_name').sum().sort_values(('surface_total_in_m2'),ascending=False).head(10)
# Out:
#                surface_total_in_m2
# place_name
# Belgrano                 1427043.0
# Palermo                   929747.0
# Caballito                 695628.0
# Recoleta                  685446.0
# Barrio Norte              661123.0
# Villa Urquiza             536269.0
# San Telmo                 477562.0
# Flores                    424774.0
# Villa Crespo              403125.0
# Nuñez                     371630.0

# %%
#Distribucion promedio de m2 por barrio (top10)
sells_caba_agrupada_por_sup_y_barrio = sells_caba.loc[:,['place_name','surface_total_in_m2']]
sells_caba_agrupada_por_sup_y_barrio.groupby('place_name').mean().sort_values(('surface_total_in_m2'),ascending=False).round({'surface_total_in_m2':2}).head(10)
# Out:
#                    surface_total_in_m2
# place_name
# Villa Soldati                   854.46
# Villa Riachuelo                 180.42
# San Telmo                       158.50
# Parque Avellaneda               154.30
# Zona Portuaria                  145.00
# Pompeya                         140.52
# Puerto Madero                   140.01
# Retiro                          136.60
# Palermo Chico                   127.26
# Recoleta                        126.02

# %% [markdown]
# ## Expensas

# %%
#Las expensas promedio mas caras por barrio en Capital Federal.
sells_caba_por_expensas_lugar = sells_caba.loc[:,['place_name','expenses']]
sells_caba_por_expensas_lugar = sells_caba_por_expensas_lugar[(sells_caba_por_expensas_lugar['expenses'] < 100000) & (sells_caba_por_expensas_lugar['expenses'] > 10)]
sells_caba_por_expensas_lugar = sells_caba_por_expensas_lugar[np.isfinite(sells_caba_por_expensas_lugar['expenses'])]
sells_caba_por_expensas_lugar.groupby('place_name').mean().sort_values(('expenses'),ascending=False).round({'expenses':2}).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-4af2da5329b6> in <module>()
#       1 #Las expensas promedio mas caras por barrio en Capital Federal.
#       2 sells_caba_por_expensas_lugar = sells_caba.loc[:,['place_name','expenses']]
# ----> 3 sells_caba_por_expensas_lugar = sells_caba_por_expensas_lugar[(sells_caba_por_expensas_lugar['expenses'] < 100000) & (sells_caba_por_expensas_lugar['expenses'] > 10)]
#       4 sells_caba_por_expensas_lugar = sells_caba_por_expensas_lugar[np.isfinite(sells_caba_por_expensas_lugar['expenses'])]
#       5 sells_caba_por_expensas_lugar.groupby('place_name').mean().sort_values(('expenses'),ascending=False).round({'expenses':2}).head()
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14847)()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
#Las expensas promedio menos caras por barrio en Capital Federal.
sells_caba_por_expensas_lugar.groupby('place_name').mean().sort_values(('expenses'),ascending=False).round({'expenses':2}).tail()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-51-05c865d4910e> in <module>()
#       1 #Las expensas promedio menos caras por barrio en Capital Federal.
# ----> 2 sells_caba_por_expensas_lugar.groupby('place_name').mean().sort_values(('expenses'),ascending=False).round({'expenses':2}).tail()
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in mean(self, *args, **kwargs)
#    1017         nv.validate_groupby_func('mean', args, kwargs)
#    1018         try:
# -> 1019             return self._cython_agg_general('mean')
#    1020         except GroupByError:
#    1021             raise
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _cython_agg_general(self, how, numeric_only)
#    3125     def _cython_agg_general(self, how, numeric_only=True):
#    3126         new_items, new_blocks = self._cython_agg_blocks(
# -> 3127             how, numeric_only=numeric_only)
#    3128         return self._wrap_agged_blocks(new_items, new_blocks)
#    3129
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _cython_agg_blocks(self, how, numeric_only)
#    3171
#    3172         if len(new_blocks) == 0:
# -> 3173             raise DataError('No numeric types to aggregate')
#    3174
#    3175         return data.items, new_blocks
#
# DataError: No numeric types to aggregate

# %%
#Las expensas promedio mas caras por ciudad del Gran Buenos Aires.
sells_gba_por_expensas_lugar = sells_gba.loc[:,['place_name','expenses']]
sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar[(sells_gba_por_expensas_lugar['expenses'] < 100000) & (sells_gba_por_expensas_lugar['expenses'] > 10)]
sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar[np.isfinite(sells_gba_por_expensas_lugar['expenses'])]
sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar.groupby('place_name').agg([np.mean,np.size])
sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar.loc[sells_gba_por_expensas_lugar[('expenses','size')]>=15,:]
sells_gba_por_expensas_lugar.sort_values(('expenses','mean'), ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d48015f7128f> in <module>()
#       1 #Las expensas promedio mas caras por ciudad del Gran Buenos Aires.
#       2 sells_gba_por_expensas_lugar = sells_gba.loc[:,['place_name','expenses']]
# ----> 3 sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar[(sells_gba_por_expensas_lugar['expenses'] < 100000) & (sells_gba_por_expensas_lugar['expenses'] > 10)]
#       4 sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar[np.isfinite(sells_gba_por_expensas_lugar['expenses'])]
#       5 sells_gba_por_expensas_lugar = sells_gba_por_expensas_lugar.groupby('place_name').agg([np.mean,np.size])
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14847)()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
#Distribucion de stores en Capital Federal
sells_caba_only_store = sells_caba[sells_caba['property_type'] == 'store']
sells_caba_only_store['place_name'].value_counts()
# Out:
# Palermo                  388
# Villa Crespo             276
# Belgrano                 255
# Centro / Microcentro     230
# Barrio Norte             226
# Balvanera                196
# Monserrat                162
# Recoleta                 162
# Once                     151
# Flores                   148
# San Telmo                145
# Caballito                122
# San Nicolás              113
# Almagro                  109
# Congreso                 106
# Villa Urquiza             90
# Retiro                    81
# Nuñez                     80
# Floresta                  80
# Palermo Hollywood         76
# San Cristobal             71
# Barracas                  69
# Boedo                     68
# Tribunales                63
# Mataderos                 61
# Colegiales                60
# Villa Devoto              52
# Puerto Madero             51
# Palermo Soho              48
# Constitución              47
#                         ...
# Parque Patricios          39
# Abasto                    38
# Chacarita                 38
# Liniers                   33
# Saavedra                  30
# Villa del Parque          29
# Coghlan                   28
# Parque Chacabuco          25
# Pompeya                   22
# Palermo Viejo             21
# Villa Luro                17
# Villa General Mitre       16
# Villa Ortuzar             16
# Villa Pueyrredón          15
# Agronomía                 13
# Velez Sarsfield           11
# Las Cañitas                8
# Palermo Chico              8
# Villa Lugano               7
# Parque Avellaneda          7
# Parque Centenario          6
# Villa Soldati              5
# Catalinas                  5
# Parque Chas                4
# Villa Santa Rita           4
# Distrito Audiovisual       3
# Monte Castro               2
# Villa Riachuelo            1
# Distrito de las Artes      1
# Villa Real                 1
# Name: place_name, dtype: int64

# %%
#Distribucion de stores en Gran Buenos Aires
sells_gba_only_store = sells_gba[sells_gba['property_type'] == 'store']
sells_gba_only_store['place_name'].value_counts()
# Out:
# La Plata                          331
# Pilar                             194
# Martínez                          174
# San Isidro                        173
# Lomas de Zamora                   170
# Lanús                             166
# Olivos                            161
# La Matanza                        148
# Ramos Mejía                       128
# General San Martín                120
# Banfield                          108
# Morón                             106
# Ituzaingó                         104
# Bs.As. G.B.A. Zona Norte           99
# Tigre                              88
# Quilmes                            75
# Vicente López                      75
# San Fernando                       74
# Castelar                           74
# Haedo                              72
# Caseros                            72
# San Justo                          71
# San Miguel                         67
# Adrogué                            60
# Acassuso                           56
# Villa Ballester                    46
# Nordelta                           46
# San Martín                         43
# Temperley                          43
# Avellaneda                         42
#                                  ...
# Bs.As. G.B.A. Zona Oeste            2
# Esteban Echeverría                  2
# Marinas Golf Barrio Cerrado         2
# Los Hornos                          2
# Tortuguitas                         2
# Florencio Varela                    2
# Barrio Los Alisos                   2
# Lisandro Olmos                      2
# Villa de Mayo                       1
# La Reja                             1
# Tapiales                            1
# Villa Maipu                         1
# Villa Astolfi                       1
# Pablo Podestá                       1
# Alejandro Korn                      1
# San José                            1
# Haras Santa Maria                   1
# San Jose                            1
# La Unión                            1
# Ex La Ponderosa                     1
# Club de Campo Manuel Belgrano       1
# Trujui                              1
# Área de Promoción El Triángulo      1
# Barrio San Matías                   1
# Derqui                              1
# Tortugas Country Club               1
# La Arboleda de Maschwitz            1
# El Jagüel                           1
# González Catán                      1
# Zeballos                            1
# Name: place_name, dtype: int64

# %%
#CON ESTO SACO EL VALOR DEL DOLAR, CON CADA DATA SET DE 6 MESES, puedo obtener un dolar que irá creciendo y se puede
#almacenar en algun plot del estilo area, en donde se vea la curva de crecimiento en la que seguramente se vera .
sells_caba_with_price_currency_ars = sells_caba[sells_caba['currency'] == 'ARS']
sells_caba_with_price_currency_ars = sells_caba_with_price_currency_ars.loc[:,['price','price_aprox_usd']]
sells_caba_with_price_currency_ars['price'].sum()/sells_caba_with_price_currency_ars['price_aprox_usd'].sum()
# Out:
# 9.100047165755877

# %% [markdown]
# # Valor del dólar durante el transcurso del mes Enero del 2017
#
# ###### Se inicia un análisis de las propiedades que se encuentran pesificadas, ya que cuentan con su valor tanto en pesos y en dolar.

# %%
#Me quedo con los valores que esten pesificados, ya que con ellos puedo trabajar para obtener el valor del dolar.

only_sells_with_price_arg = sells_caba[sells_caba['currency'] == 'ARS']
only_sells_with_price_arg = only_sells_with_price_arg [(only_sells_with_price_arg['created_on']>'2017-01-01') & (only_sells_with_price_arg['created_on']<'2017-01-31')]
#only_sells_with_price_arg = only_sells_with_price_arg [(only_sells_with_price_arg['created_on']>='2017-01-01') & (only_sells_with_price_arg['created_on']<='2017-01-31')]
#(arriba) esto con la restricciones de filtrado, lo debo quitar.
sells_caba_with_date = only_sells_with_price_arg.loc[:,['created_on','price','price_aprox_usd']]

#Con un valor de una propiedad por día puedo sacar el valor del dolar del mismo día.
sells_caba_with_date = sells_caba_with_date.drop_duplicates(['created_on'], keep='last')
sells_caba_with_date['created_on'] = sells_caba_with_date['created_on'].astype("datetime64")
sells_caba_with_date = sells_caba_with_date.sort_values(('created_on'), ascending=True)

#Agrego una columna donde voy a calcular el dolar del día.
sells_caba_with_date['dollar'] = sells_caba_with_date['price']/sells_caba_with_date['price_aprox_usd']
sells_caba_with_date = sells_caba_with_date.round({'dollar':2})
sells_caba_with_date.set_index('created_on', inplace=True)

# %%
bar = sells_caba_with_date['dollar'].plot.bar(figsize=(8,8), fontsize=15,color = 'orange',stacked=True)
bar.set_xticklabels(sells_caba_with_date.index.format()) # formato YYYY-MM-DD
bar.set_xlabel('Fecha(YYYY-MM-DD)', fontsize=15)
bar.set_ylabel('USD',fontsize = 15)
 
plt.show()
