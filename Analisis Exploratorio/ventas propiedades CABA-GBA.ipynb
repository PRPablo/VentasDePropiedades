# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %%
sells = pd.read_csv('data/sell.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93b12963746b> in <module>()
# ----> 1 sells = pd.read_csv('data/sell.csv')
#
# NameError: name 'pd' is not defined

# %%
sells.head()
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 2  e06d6f864a0b91346594da4d27ceddcef0947ea6  2012-11-01      sell
# 3  a07927207d2a03de5f4ba7fd76f670d6285a3315  2012-11-26      sell
# 4  9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
# 2     apartment         Mar del Plata
# 3         house  Sierra de los Padres
# 4         house             Mataderos
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 2  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...

# %%
sells.columns.values
# Out:
# array(['id', 'created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name',
#        'geonames_id', 'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'floor', 'rooms', 'expenses', 'properati_url',
#        'description', 'title', 'image_thumbnail'], dtype=object)

# %%
for name in sells.columns.values:
    print(name)
# Out:
# id
# created_on
# operation
# property_type
# place_name
# place_with_parent_names
# country_name
# state_name
# geonames_id
# lat-lon
# lat
# lon
# price
# currency
# price_aprox_local_currency
# price_aprox_usd
# surface_total_in_m2
# surface_covered_in_m2
# price_usd_per_m2
# price_per_m2
# floor
# rooms
# expenses
# properati_url
# description
# title
# image_thumbnail

# %%
sells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187482 entries, 0 to 187481
# Data columns (total 27 columns):
# id                            187482 non-null object
# created_on                    187482 non-null object
# operation                     187482 non-null object
# property_type                 187482 non-null object
# place_name                    187447 non-null object
# place_with_parent_names       187482 non-null object
# country_name                  187482 non-null object
# state_name                    187482 non-null object
# geonames_id                   158318 non-null float64
# lat-lon                       118761 non-null object
# lat                           118761 non-null float64
# lon                           118761 non-null float64
# price                         154443 non-null float64
# currency                      154441 non-null object
# price_aprox_local_currency    154443 non-null float64
# ...

# %%
print(sells.shape)
# Out:
# (187482, 27)

# %%
print(sells.isnull().any())
# Out:
# id                            False
# created_on                    False
# operation                     False
# property_type                 False
# place_name                     True
# place_with_parent_names       False
# country_name                  False
# state_name                    False
# geonames_id                    True
# lat-lon                        True
# lat                            True
# lon                            True
# price                          True
# currency                       True
# price_aprox_local_currency     True
# price_aprox_usd                True
# surface_total_in_m2            True
# surface_covered_in_m2          True
# price_usd_per_m2               True
# price_per_m2                   True
# floor                          True
# rooms                          True
# expenses                       True
# properati_url                 False
# description                    True
# title                         False
# ...

# %%
sells.isnull().sum()
# Out:
# id                                 0
# created_on                         0
# operation                          0
# property_type                      0
# place_name                        35
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    29164
# lat-lon                        68721
# lat                            68721
# lon                            68721
# price                          33039
# currency                       33041
# price_aprox_local_currency     33039
# price_aprox_usd                33039
# surface_total_in_m2            62455
# surface_covered_in_m2          35062
# price_usd_per_m2               82458
# price_per_m2                   55817
# floor                         173188
# rooms                         107162
# expenses                      169962
# properati_url                      0
# description                        9
# ...

# %%
print(sells.describe())
# Out:
#         geonames_id            lat            lon         price  \
# count  1.583180e+05  118761.000000  118761.000000  1.544430e+05
# mean   3.560821e+06     -34.775631     -59.207578  4.402848e+05
# std    3.442029e+05       2.071562       2.293300  1.915257e+06
# min    3.427208e+06     -54.833014     -75.678931  0.000000e+00
# 25%    3.430116e+06     -34.729040     -58.718531  1.050000e+05
# 50%    3.433359e+06     -34.604154     -58.483665  1.800000e+05
# 75%    3.832260e+06     -34.457223     -58.383317  3.950000e+05
# max    6.948895e+06       4.545843     -40.149218  6.500000e+08
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                1.544430e+05     1.544430e+05        125027.000000
# mean                 4.298946e+06     2.436423e+05           297.023707
# std                  6.870371e+06     3.893775e+05          2072.795972
# min                  0.000000e+00     0.000000e+00             0.000000
# ...

# %%
sells_capital = sells[sells['state_name'] == 'Capital Federal']
sells_capital.count()
# Out:
# id                            44152
# created_on                    44152
# operation                     44152
# property_type                 44152
# place_name                    44152
# place_with_parent_names       44152
# country_name                  44152
# state_name                    44152
# geonames_id                   42326
# lat-lon                       34180
# lat                           34180
# lon                           34180
# price                         39480
# currency                      39480
# price_aprox_local_currency    39480
# price_aprox_usd               39480
# surface_total_in_m2           35611
# surface_covered_in_m2         40507
# price_usd_per_m2              31758
# price_per_m2                  36915
# floor                          4652
# rooms                         22271
# expenses                       8226
# properati_url                 44152
# description                   44152
# title                         44152
# ...

# %%
sells_bsas = sells.loc[sells['state_name'].str.contains(r'(apital|G.B.A)')]

sells_bsas.head(100)
# Out:
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':
#                                            id  created_on operation  \
# 0    c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1    a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 4    9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
# 5    4d3b492ed5f9c74cdf33b56b98328e5c950e3f9c  2013-01-04      sell
# 6    535441f569473f6e5d687c38b27d9b9c6e69e284  2013-01-09      sell
# 10   61f3789618edabeaa7b5fc06ff36112f8a06557f  2013-01-26      sell
# 12   e842ed22eac89b9bffff146377abfd5bceb0b0cd  2013-02-08      sell
# 13   4dcfa9a54bdd18cd5438221c6dcfa94738c11c40  2013-02-15      sell
# 28   c60df01c06fe62d91c4767830ee14890fa4d73ec  2013-03-23      sell
# 29   0f0e301809a14b8c069b267fa1c56a3b5ec35d9e  2013-03-23      sell
# ...

# %%
sells_capital = sells_bsas[sells_bsas['state_name'] == 'Capital Federal']
sells_capital.count()
# Out:
# id                            44152
# created_on                    44152
# operation                     44152
# property_type                 44152
# place_name                    44152
# place_with_parent_names       44152
# country_name                  44152
# state_name                    44152
# geonames_id                   42326
# lat-lon                       34180
# lat                           34180
# lon                           34180
# price                         39480
# currency                      39480
# price_aprox_local_currency    39480
# price_aprox_usd               39480
# surface_total_in_m2           35611
# surface_covered_in_m2         40507
# price_usd_per_m2              31758
# price_per_m2                  36915
# floor                          4652
# rooms                         22271
# expenses                       8226
# properati_url                 44152
# description                   44152
# title                         44152
# ...

# %%
sells_capital_usd_price_m2 = sells_capital.loc[:,['state_name','place_name','price_usd_per_m2','price_aprox_usd','surface_total_in_m2']]
sells_capital_usd_price_m2.head(10)
# Out:
#           state_name     place_name  price_usd_per_m2  price_aprox_usd  \
# 4    Capital Federal      Mataderos        616.666667         185000.0
# 42   Capital Federal       Barracas        921.052632         140000.0
# 107  Capital Federal       Paternal       1329.113924         210000.0
# 162  Capital Federal       Barracas       1333.333333          80000.0
# 189  Capital Federal       Congreso       1642.857143         138000.0
# 295  Capital Federal     Villa Real       1538.461538         220000.0
# 347  Capital Federal  Villa Urquiza       1944.444444         175000.0
# 357  Capital Federal      Mataderos       1327.160494         215000.0
# 358  Capital Federal      Monserrat       2021.276596         190000.0
# 366  Capital Federal        Almagro       1732.558140         149000.0
#
#      surface_total_in_m2
# 4                  300.0
# 42                 152.0
# 107                158.0
# 162                 60.0
# 189                 84.0
# 295                143.0
# ...

# %%
sells_matederos = sells_capital_usd_price_m2.loc[sells_capital_usd_price_m2['place_name'].str.contains(r'(uerto)')]
sells_matederos.mean()
# Out:
# /home/prp-admin/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':
# price_usd_per_m2         5829.246025
# price_aprox_usd        933102.405806
# surface_total_in_m2       161.411178
# dtype: float64
